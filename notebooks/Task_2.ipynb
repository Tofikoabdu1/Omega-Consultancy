# %%
import pandas as pd
df = pd.read_csv('../data/processed/all_reviews_with_sentiment.csv')
print(df.shape)
print(df['bank'].value_counts())
print((df['review'].isna().mean())*100)
# Out:
# (1455, 10)
# bank
# BOA       516
# Dashen    488
# CBE       451
# Name: count, dtype: int64
# 0.0

# %%
df.head(100)
# Out:
#                                 reviewId  \
# 0   3463230e-f9f7-4be3-a632-fdd8d017ce84
# 1   a6cbfa34-f2b1-4a16-96b6-c94f58cea76f
# 2   fc67d12c-92e2-45aa-a9e0-011f58a583bc
# 3   11306fb9-5571-4950-8d32-604c5402242f
# 4   809c46d2-730e-446a-9061-2a45e978ad9d
# ..                                   ...
# 95  ac500ef1-8d40-4c19-b862-c5f47b165e97
# 96  e080468a-5b05-476e-9275-923d859a7b98
# 97  cd3d7bda-43cf-46f8-bd12-065f026e2ba2
# 98  17d27fe8-201d-465e-900c-4510058bd581
# 99  161dbde7-f447-412e-abf3-8ae5e7ba5012
#
#                                                review  rating        date  \
# 0                                                  🙏👍       5  2025-11-29
# 1                                           Very Good       5  2025-11-28
# 2                                                goof       5  2025-11-28
# 3                                               good!       5  2025-11-28
# 4                                            good jop       5  2025-11-27
# ...
